# %% [markdown]
# ## Single-cell rna demo

# %%
# !pip install umap-learn
# !pip install kneed
# !pip install gower
# !pip install kmodes
# !pip install pandas matplotlib datashader bokeh holoviews scikit-image colorcet
# Out:
# Collecting umap-learn
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.3.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 4.5 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.13 umap-learn-0.5.6
# Collecting kneed
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.13.1)
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.5
# Collecting gower
#   Downloading gower-0.1.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gower) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gower) (1.13.1)
# Downloading gower-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: gower
# Successfully installed gower-0.1.2
# Collecting kmodes
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.3.2)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.13.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->kmodes) (3.5.0)
# Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting datashader
#   Downloading datashader-0.16.3-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (3.4.3)
# Requirement already satisfied: holoviews in /usr/local/lib/python3.10/dist-packages (1.18.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.23.2)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from datashader) (2024.7.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from datashader) (1.0.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from datashader) (0.60.0)
# Requirement already satisfied: param in /usr/local/lib/python3.10/dist-packages (from datashader) (2.1.1)
# Collecting pyct (from datashader)
#   Downloading pyct-0.5.0-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from datashader) (2.32.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datashader) (1.13.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from datashader) (0.12.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from datashader) (2024.6.0)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2024.6.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.10/dist-packages (from holoviews) (3.0.3)
# Requirement already satisfied: panel>=1.0 in /usr/local/lib/python3.10/dist-packages (from holoviews) (1.4.5)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.3)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2024.7.24)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh) (2.1.5)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->holoviews) (3.6)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->holoviews) (3.0.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->holoviews) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->holoviews) (0.4.1)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->holoviews) (4.66.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->holoviews) (6.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->holoviews) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (2024.6.1)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (1.4.2)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (8.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->datashader) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (2024.7.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask->datashader) (3.19.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask->datashader) (1.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel>=1.0->holoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py->panel>=1.0->holoviews) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->panel>=1.0->holoviews) (0.1.2)
# Downloading datashader-0.16.3-py2.py3-none-any.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 19.8 MB/s eta 0:00:00
# Downloading pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: pyct, datashader
# Successfully installed datashader-0.16.3 pyct-0.5.0

# %%
import json

import pandas as pd
import numpy as np

from scipy.io import mmread

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import adjusted_rand_score
from sklearn.decomposition import PCA
from sklearn.metrics import adjusted_rand_score

from yellowbrick.cluster import SilhouetteVisualizer

import umap
import umap.plot as uplot

from kneed import KneeLocator
import random

random.seed(12)

sns.set_theme()
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/cudf/utils/_ptxcompiler.py:61: UserWarning: Error getting driver and runtime versions:
#
# stdout:
#
#
#
# stderr:
#
# Traceback (most recent call last):
#   File "<string>", line 4, in <module>
#   File "/usr/local/lib/python3.10/dist-packages/numba/cuda/cudadrv/driver.py", line 295, in __getattr__
#     raise CudaSupportError("Error at driver init: \n%s:" %
# numba.cuda.cudadrv.error.CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :
#
#
# Not patching Numba
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/cudf/utils/gpu_utils.py:62: UserWarning: Failed to dlopen libcuda.so.1
#   warnings.warn(str(e))
# /usr/local/lib/python3.10/dist-packages/cudf/utils/gpu_utils.py:62: UserWarning: Function "cuInit" not found
#   warnings.warn(str(e))
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
#   warnings.warn(msg, errors.NumbaWarning)
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
#   warnings.warn(msg, errors.NumbaWarning)
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
#   warnings.warn(msg, errors.NumbaWarning)

# %% [markdown]
# ## Load the data
#
# Single-cell RNA sequencing (scRNA-seq) is a technique used to study the gene expression patterns of individual cells.

# %%
# Load the dataset
cell_names_path = '/content/barcodes.tsv'
gene_names_path = '/content/genes.tsv'
data_path = '/content/matrix.mtx'

cell_names = pd.read_csv(cell_names_path, sep='\t', header=None)[0]
gene_names = pd.read_csv(gene_names_path, sep='\t', header=None)[1]

# %%
# Load cell annotations
cell_annotations_path = '/content/pmbc_3k_cell_types.json'
fle = open(cell_annotations_path, 'r')
cell_type_dict = json.load(fle)
fle.close()

# %%
cell_type_dict
# Out:
# {'AAACATACAACCAC-1': 'Memory CD4 T',
#  'AAACATTGAGCTAC-1': 'B-cells',
#  'AAACATTGATCAGC-1': 'Memory CD4 T',
#  'AAACCGTGCTTCCG-1': 'CD14+ Mono',
#  'AAACCGTGTATGCG-1': 'NK cells',
#  'AAACGCACTGGTAC-1': 'Memory CD4 T',
#  'AAACGCTGACCAGT-1': 'CD8 T',
#  'AAACGCTGGTTCTT-1': 'CD8 T',
#  'AAACGCTGTAGCCA-1': 'Naive CD4 T',
#  'AAACGCTGTTTCTG-1': 'FCGR3A+ Mono',
#  'AAACTTGAAAAACG-1': 'B-cells',
#  'AAACTTGATCCAGA-1': 'Naive CD4 T',
#  'AAAGAGACGAGATA-1': 'Naive CD4 T',
#  'AAAGAGACGCGAGA-1': 'CD14+ Mono',
#  'AAAGAGACGGACTT-1': 'Naive CD4 T',
#  'AAAGAGACGGCATT-1': 'Naive CD4 T',
#  'AAAGCAGATATCGG-1': 'CD14+ Mono',
#  'AAAGCCTGTATGCG-1': 'Memory CD4 T',
#  'AAAGGCCTGTCTAG-1': 'B-cells',
#  'AAAGTTTGATCACG-1': 'B-cells',
#  'AAAGTTTGGGGTGA-1': 'B-cells',
#  'AAAGTTTGTAGAGA-1': 'Naive CD4 T',
#  'AAAGTTTGTAGCGT-1': 'CD14+ Mono',
#  'AAATCAACAATGCC-1': 'B-cells',
#  'AAATCAACACCAGT-1': 'Naive CD4 T',
#  'AAATCAACCAGGAG-1': 'Naive CD4 T',
#  'AAATCAACCCTATT-1': 'FCGR3A+ Mono',
#  'AAATCAACGGAAGC-1': 'Naive CD4 T',
#  'AAATCAACTCGCAA-1': 'Memory CD4 T',
#  'AAATCATGACCACA-1': 'FCGR3A+ Mono',
#  'AAATCCCTCCACAA-1': 'Naive CD4 T',
#  'AAATCCCTGCTATG-1': 'B-cells',
#  'AAATGTTGAACGAA-1': 'CD14+ Mono',
#  'AAATGTTGCCACAA-1': 'Memory CD4 T',
#  'AAATGTTGTGGCAT-1': 'CD14+ Mono',
#  'AAATTCGAAGGTTC-1': 'Naive CD4 T',
#  'AAATTCGAATCACG-1': 'CD14+ Mono',
#  'AAATTCGAGCTGAT-1': 'FCGR3A+ Mono',
#  'AAATTCGAGGAGTG-1': 'Naive CD4 T',
#  'AAATTCGATTCTCA-1': 'CD8 T',
#  'AAATTGACACGACT-1': 'CD8 T',
#  'AAATTGACTCGCTC-1': 'Memory CD4 T',
#  'AACAAACTCATTTC-1': 'Naive CD4 T',
#  'AACAAACTTTCGTT-1': 'Naive CD4 T',
#  'AACAATACGACGAG-1': 'Naive CD4 T',
#  'AACACGTGCAGAGG-1': 'Memory CD4 T',
#  'AACACGTGGAAAGT-1': 'Naive CD4 T',
#  'AACACGTGGAACCT-1': 'CD14+ Mono',
#  'AACACGTGGCTACA-1': 'Naive CD4 T',
#  'AACACGTGTACGAC-1': 'FCGR3A+ Mono',
#  'AACAGCACAAGAGT-1': 'CD14+ Mono',
#  'AACATTGATGGGAG-1': 'FCGR3A+ Mono',
#  'AACCAGTGATACCG-1': 'FCGR3A+ Mono',
#  'AACCCAGATCGCTC-1': 'Naive CD4 T',
#  'AACCGATGCTCCCA-1': 'Naive CD4 T',
#  'AACCGATGGTCATG-1': 'B-cells',
#  'AACCGATGTTCTAC-1': 'CD14+ Mono',
#  'AACCGCCTAGCGTT-1': 'Memory CD4 T',
#  'AACCGCCTCTACGA-1': 'CD14+ Mono',
#  'AACCTACTGTGAGG-1': 'CD14+ Mono',
#  'AACCTACTGTGTTG-1': 'Naive CD4 T',
#  'AACCTTACGAGACG-1': 'Naive CD4 T',
#  'AACCTTACGCGAGA-1': 'NK cells',
#  'AACCTTACTAACGC-1': 'FCGR3A+ Mono',
#  'AACCTTTGGACGGA-1': 'Naive CD4 T',
#  'AACCTTTGTACGCA-1': 'FCGR3A+ Mono',
#  'AACGCAACAAGTAG-1': 'Memory CD4 T',
#  'AACGCATGACCCAA-1': 'Naive CD4 T',
#  'AACGCATGCCTTCG-1': 'Naive CD4 T',
#  'AACGCATGTACTTC-1': 'Naive CD4 T',
#  'AACGCCCTCGGGAA-1': 'Memory CD4 T',
#  'AACGCCCTCGTACA-1': 'NK cells',
#  'AACGCCCTGGCATT-1': 'Memory CD4 T',
#  'AACGTCGAGTATCG-1': 'NK cells',
#  'AACGTGTGAAAGCA-1': 'Naive CD4 T',
#  'AACGTGTGGCGGAA-1': 'B-cells',
#  'AACGTGTGTCCAAG-1': 'Naive CD4 T',
#  'AACGTGTGTGCTTT-1': 'Memory CD4 T',
#  'AACTACCTTAGAGA-1': 'Naive CD4 T',
#  'AACTCACTCAAGCT-1': 'CD14+ Mono',
#  'AACTCACTTGGAGG-1': 'CD14+ Mono',
#  'AACTCGGAAAGTGA-1': 'CD8 T',
#  'AACTCGGAAGGTCT-1': 'CD14+ Mono',
#  'AACTCTTGCAGGAG-1': 'Memory CD4 T',
#  'AACTGTCTCCCTTG-1': 'CD14+ Mono',
#  'AACTTGCTACGCTA-1': 'B-cells',
#  'AACTTGCTGGGACA-1': 'Naive CD4 T',
#  'AAGAACGAGTGTTG-1': 'Naive CD4 T',
#  'AAGAAGACGTAGGG-1': 'B-cells',
#  'AAGACAGAAGTCTG-1': 'B-cells',
#  'AAGACAGAGGATCT-1': 'Naive CD4 T',
#  'AAGACAGATTACCT-1': 'CD14+ Mono',
#  'AAGAGATGGGTAGG-1': 'B-cells',
#  'AAGATGGAAAACAG-1': 'B-cells',
#  'AAGATGGAGAACTC-1': 'CD14+ Mono',
#  'AAGATGGAGATAAG-1': 'CD14+ Mono',
#  'AAGATTACAACCTG-1': 'Naive CD4 T',
#  'AAGATTACAGATCC-1': 'CD14+ Mono',
#  'AAGATTACCCGTTC-1': 'CD14+ Mono',
#  'AAGATTACCGCCTT-1': 'DC cells',
#  'AAGATTACCTCAAG-1': 'NK cells',
#  'AAGATTACTCCTCG-1': 'CD14+ Mono',
#  'AAGCAAGAGCGAGA-1': 'Memory CD4 T',
#  'AAGCAAGAGCTTAG-1': 'NK cells',
#  'AAGCAAGAGGTGTT-1': 'NK cells',
#  'AAGCACTGAGCAAA-1': 'B-cells',
#  'AAGCACTGCATACG-1': 'Naive CD4 T',
#  'AAGCACTGGTTCTT-1': 'B-cells',
#  'AAGCCAACGTGTTG-1': 'Naive CD4 T',
#  'AAGCCATGAACTGC-1': 'DC cells',
#  'AAGCCATGACACGT-1': 'CD14+ Mono',
#  'AAGCCATGCGTGAT-1': 'Naive CD4 T',
#  'AAGCCATGTCTCGC-1': 'Naive CD4 T',
#  'AAGCCTGACATGCA-1': 'Memory CD4 T',
#  'AAGCCTGACCGAAT-1': 'CD14+ Mono',
#  'AAGCGACTCCTCAC-1': 'FCGR3A+ Mono',
#  'AAGCGACTGTGTCA-1': 'Naive CD4 T',
#  'AAGCGACTTACAGC-1': 'B-cells',
#  'AAGCGACTTTGACG-1': 'FCGR3A+ Mono',
#  'AAGCGTACGTCTTT-1': 'Naive CD4 T',
#  'AAGGCTTGCGAACT-1': 'CD8 T',
#  'AAGGTCACGGTTAC-1': 'CD14+ Mono',
#  'AAGGTCACTGTTTC-1': 'B-cells',
#  'AAGGTCACTTCCCG-1': 'CD8 T',
#  'AAGGTCTGACAGTC-1': 'Memory CD4 T',
#  'AAGGTCTGCAGATC-1': 'Naive CD4 T',
#  'AAGTAACTCTGAAC-1': 'CD14+ Mono',
#  'AAGTAACTGAGATA-1': 'B-cells',
#  'AAGTAGGATACAGC-1': 'NK cells',
#  'AAGTATACCGAACT-1': 'Naive CD4 T',
#  'AAGTCCGACTTGTT-1': 'Naive CD4 T',
#  'AAGTCCGATAGAAG-1': 'Naive CD4 T',
#  'AAGTCTCTAGTCGT-1': 'Naive CD4 T',
#  'AAGTCTCTCGGAGA-1': 'CD8 T',
#  'AAGTGGCTTGGAGG-1': 'B-cells',
#  'AAGTTCCTCATTCT-1': 'FCGR3A+ Mono',
#  'AAGTTCCTTCTTAC-1': 'Memory CD4 T',
#  'AATAAGCTCGAATC-1': 'Memory CD4 T',
#  'AATAAGCTCGTTGA-1': 'Naive CD4 T',
#  'AATACCCTGGACGA-1': 'B-cells',
#  'AATACCCTGGCATT-1': 'Memory CD4 T',
#  'AATACTGAAAGGGC-1': 'CD8 T',
#  'AATACTGAATTGGC-1': 'NK cells',
#  'AATAGGGAACCCTC-1': 'B-cells',
#  'AATAGGGAGAATGA-1': 'CD8 T',
#  'AATCAAACTATCGG-1': 'CD8 T',
#  'AATCCGGAATGCTG-1': 'B-cells',
#  'AATCCTACCGGTAT-1': 'Naive CD4 T',
#  'AATCCTTGACGGGA-1': 'CD14+ Mono',
#  'AATCCTTGGTGAGG-1': 'NK cells',
#  'AATCGGTGGAACTC-1': 'CD8 T',
#  'AATCGGTGTGCTTT-1': 'Naive CD4 T',
#  'AATCTAGAAAAGTG-1': 'Memory CD4 T',
#  'AATCTAGAATCGGT-1': 'Naive CD4 T',
#  'AATCTCACAGCCTA-1': 'CD14+ Mono',
#  'AATCTCACTCTAGG-1': 'Naive CD4 T',
#  'AATCTCTGAACAGA-1': 'Naive CD4 T',
#  'AATCTCTGCTTTAC-1': 'NK cells',
#  'AATGATACACCAAC-1': 'CD8 T',
#  'AATGATACGGTCAT-1': 'CD14+ Mono',
#  'AATGCGTGACACCA-1': 'B-cells',
#  'AATGCGTGGACGGA-1': 'CD14+ Mono',
#  'AATGCGTGGCTATG-1': 'B-cells',
#  'AATGGAGAATCGTG-1': 'CD14+ Mono',
#  'AATGGAGATCCTTA-1': 'CD8 T',
#  'AATGGCTGACACCA-1': 'B-cells',
#  'AATGGCTGCGTGAT-1': 'Memory CD4 T',
#  'AATGGCTGTAAAGG-1': 'CD8 T',
#  'AATGGCTGTACTCT-1': 'CD8 T',
#  'AATGGCTGTGAAGA-1': 'Naive CD4 T',
#  'AATGTAACGGTGGA-1': 'Naive CD4 T',
#  'AATGTCCTCTTCTA-1': 'Memory CD4 T',
#  'AATGTTGACAGTCA-1': 'Memory CD4 T',
#  'AATGTTGAGTTGAC-1': 'CD14+ Mono',
#  'AATGTTGATCTACT-1': 'Memory CD4 T',
#  'AATTACGAATTCCT-1': 'DC cells',
#  'AATTACGACTTCTA-1': 'Naive CD4 T',
#  'AATTACGAGTGAGG-1': 'Memory CD4 T',
#  'AATTACGATTGGCA-1': 'B-cells',
#  'AATTCCTGCTCAGA-1': 'B-cells',
#  'AATTGATGTCGCAA-1': 'FCGR3A+ Mono',
#  'AATTGTGACTTGGA-1': 'B-cells',
#  'ACAAAGGAGGGTGA-1': 'Naive CD4 T',
#  'ACAAATTGATTCTC-1': 'FCGR3A+ Mono',
#  'ACAAATTGCTCAGA-1': 'CD14+ Mono',
#  'ACAAATTGTTGCGA-1': 'NK cells',
#  'ACAACCGAGGGATG-1': 'NK cells',
#  'ACAACCGAGTTACG-1': 'Memory CD4 T',
#  'ACAAGAGAAGTCGT-1': 'CD14+ Mono',
#  'ACAAGAGACTTATC-1': 'Naive CD4 T',
#  'ACAAGAGAGTTGAC-1': 'B-cells',
#  'ACAATCCTAACCGT-1': 'Memory CD4 T',
#  'ACAATCCTTAGCGT-1': 'B-cells',
#  'ACAATTGACTGACA-1': 'CD8 T',
#  'ACAATTGATGACTG-1': 'NK cells',
#  'ACACAGACCATACG-1': 'CD8 T',
#  'ACACCAGAGGGCAA-1': 'CD8 T',
#  'ACACCCTGGTGTTG-1': 'NK cells',
#  'ACACGAACAGTTCG-1': 'Memory CD4 T',
#  'ACACGATGACGCAT-1': 'CD8 T',
#  'ACACGATGATGTGC-1': 'CD14+ Mono',
#  'ACACGATGTCGTAG-1': 'CD8 T',
#  'ACACGATGTGGTCA-1': 'CD8 T',
#  'ACAGACACGGCATT-1': 'Memory CD4 T',
#  'ACAGACACGTTGTG-1': 'Memory CD4 T',
#  'ACAGCAACACCTAG-1': 'CD14+ Mono',
#  'ACAGCAACCTCAAG-1': 'FCGR3A+ Mono',
#  'ACAGGTACCCCACT-1': 'Naive CD4 T',
#  'ACAGGTACGCTGTA-1': 'CD8 T',
#  'ACAGGTACTGGTGT-1': 'NK cells',
#  'ACAGTCGACCCAAA-1': 'Naive CD4 T',
#  'ACAGTCGACCGATA-1': 'CD8 T',
#  'ACAGTGACTCACCC-1': 'CD8 T',
#  'ACAGTGACTCTATC-1': 'CD8 T',
#  'ACAGTGTGGTCACA-1': 'Naive CD4 T',
#  'ACAGTGTGTTGCGA-1': 'CD14+ Mono',
#  'ACATCACTCTACTT-1': 'CD14+ Mono',
#  'ACATGGTGAAGCCT-1': 'Naive CD4 T',
#  'ACATGGTGCAACCA-1': 'B-cells',
#  'ACATGGTGCGAGTT-1': 'Naive CD4 T',
#  'ACATTCTGGCATAC-1': 'Naive CD4 T',
#  'ACATTCTGGGAACG-1': 'CD14+ Mono',
#  'ACCAACGACATGCA-1': 'Naive CD4 T',
#  'ACCACAGAAAGTAG-1': 'Naive CD4 T',
#  'ACCACAGAGTTGGT-1': 'Naive CD4 T',
#  'ACCACCTGTGTGCA-1': 'Naive CD4 T',
#  'ACCACGCTACAGCT-1': 'Naive CD4 T',
#  'ACCACGCTACCCAA-1': 'CD8 T',
#  'ACCACGCTGCGAGA-1': 'Naive CD4 T',
#  'ACCACGCTGCTGTA-1': 'Naive CD4 T',
#  'ACCAGCCTGACAGG-1': 'Memory CD4 T',
#  'ACCAGTGAACGGTT-1': 'B-cells',
#  'ACCAGTGAATACCG-1': 'FCGR3A+ Mono',
#  'ACCAGTGAGGGATG-1': 'Naive CD4 T',
#  'ACCAGTGATGACTG-1': 'CD14+ Mono',
#  'ACCATTACCTTCTA-1': 'Naive CD4 T',
#  'ACCATTACGAGATA-1': 'Memory CD4 T',
#  'ACCATTTGTCATTC-1': 'Naive CD4 T',
#  'ACCCAAGAACTGTG-1': 'CD8 T',
#  'ACCCAAGAATTCCT-1': 'FCGR3A+ Mono',
#  'ACCCAAGAGGACAG-1': 'Memory CD4 T',
#  'ACCCAAGATTCACT-1': 'B-cells',
#  'ACCCACTGCGCCTT-1': 'CD14+ Mono',
#  'ACCCACTGGACAGG-1': 'Naive CD4 T',
#  'ACCCACTGGTTCAG-1': 'Platelet',
#  'ACCCACTGTCGTAG-1': 'CD14+ Mono',
#  'ACCCAGCTCAGAAA-1': 'Memory CD4 T',
#  'ACCCAGCTGTTAGC-1': 'CD14+ Mono',
#  'ACCCAGCTTGCTTT-1': 'Naive CD4 T',
#  'ACCCGTTGATGACC-1': 'B-cells',
#  'ACCCGTTGCTGCAA-1': 'Naive CD4 T',
#  'ACCCGTTGCTTCTA-1': 'DC cells',
#  'ACCCTCGACCTATT-1': 'Memory CD4 T',
#  'ACCCTCGACGGTAT-1': 'B-cells',
#  'ACCCTCGATAAGGA-1': 'CD14+ Mono',
#  'ACCCTCGATCAAGC-1': 'FCGR3A+ Mono',
#  'ACCGTGCTACCAGT-1': 'Memory CD4 T',
#  'ACCGTGCTGGAACG-1': 'B-cells',
#  'ACCTATTGCTGAGT-1': 'B-cells',
#  'ACCTATTGTGCCCT-1': 'FCGR3A+ Mono',
#  'ACCTCCGAGTCCTC-1': 'Memory CD4 T',
#  'ACCTCCGATATGCG-1': 'Naive CD4 T',
#  'ACCTCCGATGCTGA-1': 'Naive CD4 T',
#  'ACCTCGTGAACCAC-1': 'CD8 T',
#  'ACCTGAGATATCGG-1': 'Platelet',
#  'ACCTGGCTAAGTAG-1': 'NK cells',
#  'ACCTTTGACTCCCA-1': 'CD14+ Mono',
#  'ACCTTTGAGGAACG-1': 'CD14+ Mono',
#  'ACCTTTGAGGAAGC-1': 'CD14+ Mono',
#  'ACGAACACCTTGTT-1': 'NK cells',
#  'ACGAACTGGCTATG-1': 'Platelet',
#  'ACGAAGCTCTCCAC-1': 'Naive CD4 T',
#  'ACGAAGCTCTGAGT-1': 'B-cells',
#  'ACGACCCTATCTCT-1': 'FCGR3A+ Mono',
#  'ACGACCCTGATGAA-1': 'Naive CD4 T',
#  'ACGACCCTTGACAC-1': 'B-cells',
#  'ACGACCCTTGACCA-1': 'Naive CD4 T',
#  'ACGAGGGACAGGAG-1': 'DC cells',
#  'ACGAGGGACGAACT-1': 'Naive CD4 T',
#  'ACGAGGGATGTAGC-1': 'Memory CD4 T',
#  'ACGAGTACCCTAAG-1': 'B-cells',
#  'ACGAGTACGAATCC-1': 'B-cells',
#  'ACGATCGAGGACTT-1': 'CD8 T',
#  'ACGATCGAGTCACA-1': 'CD14+ Mono',
#  'ACGATGACAATGCC-1': 'Memory CD4 T',
#  'ACGATGACTGGTCA-1': 'Memory CD4 T',
#  'ACGATTCTACGGGA-1': 'Naive CD4 T',
#  'ACGCAATGGTTCAG-1': 'NK cells',
#  'ACGCACCTGTTAGC-1': 'B-cells',
#  'ACGCCACTGAACTC-1': 'CD14+ Mono',
#  'ACGCCGGAAACCAC-1': 'CD14+ Mono',
#  'ACGCCGGAAAGCCT-1': 'Naive CD4 T',
#  'ACGCCGGAAATGCC-1': 'Memory CD4 T',
#  'ACGCCTTGCTCCCA-1': 'FCGR3A+ Mono',
#  'ACGCGGTGGCGAGA-1': 'Memory CD4 T',
#  'ACGCGGTGTGTGGT-1': 'B-cells',
#  'ACGCGGTGTTTGCT-1': 'CD8 T',
#  'ACGCTCACAGTACC-1': 'Naive CD4 T',
#  'ACGCTCACCCTTGC-1': 'Naive CD4 T',
#  'ACGCTGCTGTTCTT-1': 'NK cells',
#  'ACGGAACTCAGATC-1': 'NK cells',
#  'ACGGAACTGTCGTA-1': 'FCGR3A+ Mono',
#  'ACGGAGGACTCTTA-1': 'CD14+ Mono',
#  'ACGGATTGGGAGGT-1': 'B-cells',
#  'ACGGATTGGTTAGC-1': 'Memory CD4 T',
#  'ACGGCTCTGAGCAG-1': 'Memory CD4 T',
#  'ACGGCTCTTGCACA-1': 'Naive CD4 T',
#  'ACGGTAACCGCTAA-1': 'CD8 T',
#  'ACGGTAACCTTCGC-1': 'CD8 T',
#  'ACGGTAACGGTGGA-1': 'Naive CD4 T',
#  'ACGGTAACTCGCAA-1': 'CD8 T',
#  'ACGGTATGAGTCGT-1': 'CD14+ Mono',
#  'ACGGTATGGGTATC-1': 'B-cells',
#  'ACGGTATGGTTGTG-1': 'B-cells',
#  'ACGGTCCTAACGGG-1': 'Memory CD4 T',
#  'ACGGTCCTCGGGAA-1': 'Naive CD4 T',
#  'ACGTAGACAACCAC-1': 'Memory CD4 T',
#  'ACGTAGACTACAGC-1': 'B-cells',
#  'ACGTCAGAAACGAA-1': 'Memory CD4 T',
#  'ACGTCAGAGAGCTT-1': 'CD14+ Mono',
#  'ACGTCAGAGGGATG-1': 'Naive CD4 T',
#  'ACGTCCTGATAAGG-1': 'CD14+ Mono',
#  'ACGTCCTGTGAACC-1': 'CD14+ Mono',
#  'ACGTCGCTCCTGAA-1': 'CD8 T',
#  'ACGTCGCTCTATTC-1': 'CD14+ Mono',
#  'ACGTCGCTTCTCAT-1': 'B-cells',
#  'ACGTGATGCCATGA-1': 'DC cells',
#  'ACGTGATGGGTCTA-1': 'Naive CD4 T',
#  'ACGTGATGTAACCG-1': 'FCGR3A+ Mono',
#  'ACGTGATGTGACAC-1': 'NK cells',
#  'ACGTGCCTCCGTAA-1': 'Memory CD4 T',
#  'ACGTGCCTTCTATC-1': 'CD8 T',
#  'ACGTTACTTTCCAT-1': 'Naive CD4 T',
#  'ACGTTGGAAAAGCA-1': 'Naive CD4 T',
#  'ACGTTGGAAACCTG-1': 'CD8 T',
#  'ACGTTGGACCGTAA-1': 'CD14+ Mono',
#  'ACGTTGGAGCCAAT-1': 'NK cells',
#  'ACGTTGGATATGGC-1': 'B-cells',
#  'ACGTTGGATCAGGT-1': 'CD14+ Mono',
#  'ACGTTTACATCAGC-1': 'Naive CD4 T',
#  'ACTAAAACCCACAA-1': 'Naive CD4 T',
#  'ACTAAAACTCGACA-1': 'CD14+ Mono',
#  'ACTACGGAATTTCC-1': 'Memory CD4 T',
#  'ACTACGGACCTATT-1': 'Naive CD4 T',
#  'ACTACGGATCGCTC-1': 'Naive CD4 T',
#  'ACTACTACTAAGGA-1': 'Naive CD4 T',
#  'ACTAGGTGGAACCT-1': 'CD8 T',
#  'ACTAGGTGGAACTC-1': 'Memory CD4 T',
#  'ACTATCACCTTGGA-1': 'CD8 T',
#  'ACTATCACTGCCAA-1': 'Naive CD4 T',
#  'ACTCAGGACTGAAC-1': 'Naive CD4 T',
#  'ACTCAGGATCTATC-1': 'B-cells',
#  'ACTCAGGATTCGTT-1': 'CD14+ Mono',
#  'ACTCCTCTCAACTG-1': 'Memory CD4 T',
#  'ACTCGCACGAAAGT-1': 'CD14+ Mono',
#  'ACTCGCACTACGAC-1': 'CD14+ Mono',
#  'ACTCTCCTGACACT-1': 'Naive CD4 T',
#  'ACTCTCCTGCATAC-1': 'Naive CD4 T',
#  'ACTCTCCTGTTTGG-1': 'Naive CD4 T',
#  'ACTGAGACAACCAC-1': 'CD8 T',
#  'ACTGAGACCCATAG-1': 'FCGR3A+ Mono',
#  'ACTGAGACGTTGGT-1': 'B-cells',
#  'ACTGCCACACACGT-1': 'CD8 T',
#  'ACTGCCACTCCGTC-1': 'NK cells',
#  'ACTGGCCTTCAGTG-1': 'NK cells',
#  'ACTGTGGACGTGTA-1': 'CD8 T',
#  'ACTGTGGATCTAGG-1': 'B-cells',
#  'ACTGTTACCCACAA-1': 'CD14+ Mono',
#  'ACTGTTACTGCAGT-1': 'Naive CD4 T',
#  'ACTTAAGAACCACA-1': 'Naive CD4 T',
#  'ACTTAAGATTACTC-1': 'DC cells',
#  'ACTTAGCTGCGTAT-1': 'FCGR3A+ Mono',
#  'ACTTAGCTGGGAGT-1': 'Memory CD4 T',
#  'ACTTCAACAAGCAA-1': 'Memory CD4 T',
#  'ACTTCAACGTAGGG-1': 'NK cells',
#  'ACTTCCCTTTCCGC-1': 'Naive CD4 T',
#  'ACTTCTGACATGCA-1': 'B-cells',
#  'ACTTGACTCCACAA-1': 'B-cells',
#  'ACTTGGGAGAAAGT-1': 'CD14+ Mono',
#  'ACTTGGGAGGTTTG-1': 'Memory CD4 T',
#  'ACTTGGGATGTGAC-1': 'FCGR3A+ Mono',
#  'ACTTGGGATTGACG-1': 'CD14+ Mono',
#  'ACTTGTACCTGTCC-1': 'Naive CD4 T',
#  'ACTTTGTGGAAAGT-1': 'Naive CD4 T',
#  'ACTTTGTGGATAGA-1': 'CD14+ Mono',
#  'AGAAACGAAAGTAG-1': 'B-cells',
#  'AGAAAGTGCGCAAT-1': 'Naive CD4 T',
#  'AGAAAGTGGGGATG-1': 'CD14+ Mono',
#  'AGAACAGAAATGCC-1': 'NK cells',
#  'AGAACAGACGACTA-1': 'B-cells',
#  'AGAACAGAGACAAA-1': 'Memory CD4 T',
#  'AGAACGCTTTGCTT-1': 'Naive CD4 T',
#  'AGAAGATGTGACTG-1': 'Memory CD4 T',
#  'AGAATGGAAGAAGT-1': 'CD8 T',
#  'AGAATTTGTAACCG-1': 'Naive CD4 T',
#  'AGAATTTGTAGAGA-1': 'Naive CD4 T',
#  'AGACACACTGTAGC-1': 'Naive CD4 T',
#  'AGACACTGTCAAGC-1': 'CD14+ Mono',
#  'AGACCTGAAGTAGA-1': 'CD14+ Mono',
#  'AGACCTGACCAACA-1': 'Memory CD4 T',
#  'AGACCTGAGGAAGC-1': 'CD8 T',
#  'AGACGTACAGAGGC-1': 'Memory CD4 T',
#  'AGACGTACCCCTAC-1': 'B-cells',
#  'AGACGTACCTCTTA-1': 'CD14+ Mono',
#  'AGACGTACTCGTGA-1': 'FCGR3A+ Mono',
#  'AGACTGACCATCAG-1': 'CD8 T',
#  'AGACTGACCCTTTA-1': 'Naive CD4 T',
#  'AGACTTCTCATGCA-1': 'B-cells',
#  'AGAGATGACAGTCA-1': 'B-cells',
#  'AGAGATGACTGAAC-1': 'Naive CD4 T',
#  'AGAGATGAGGTTTG-1': 'CD14+ Mono',
#  'AGAGATGATCTCGC-1': 'B-cells',
#  'AGAGATGATTGTGG-1': 'Naive CD4 T',
#  'AGAGCGGAGGCAAG-1': 'CD14+ Mono',
#  'AGAGTCTGGTCGTA-1': 'FCGR3A+ Mono',
#  'AGAGTGCTCAGCTA-1': 'Naive CD4 T',
#  'AGAGTGCTCGAATC-1': 'Naive CD4 T',
#  'AGAGTGCTGTCATG-1': 'Memory CD4 T',
#  'AGAGTGCTGTCCTC-1': 'CD8 T',
#  'AGAGTGCTGTGTTG-1': 'B-cells',
#  'AGATATACCCGTAA-1': 'NK cells',
#  'AGATATACGATGAA-1': 'Memory CD4 T',
#  'AGATATACTGTTCT-1': 'B-cells',
#  'AGATATTGCCTACC-1': 'CD8 T',
#  'AGATATTGGCCAAT-1': 'CD14+ Mono',
#  'AGATCGTGTCTGGA-1': 'CD14+ Mono',
#  'AGATCGTGTTTGTC-1': 'B-cells',
#  'AGATCTCTATCACG-1': 'B-cells',
#  'AGATTAACGTTCTT-1': 'FCGR3A+ Mono',
#  'AGATTCCTATCGTG-1': 'Naive CD4 T',
#  'AGATTCCTCACTTT-1': 'CD14+ Mono',
#  'AGATTCCTGACGAG-1': 'CD14+ Mono',
#  'AGATTCCTGTTCAG-1': 'NK cells',
#  'AGCAAAGATATGCG-1': 'Naive CD4 T',
#  'AGCACAACAGTCTG-1': 'Naive CD4 T',
#  'AGCACTGAGGGAGT-1': 'Memory CD4 T',
#  'AGCACTGATATGCG-1': 'Memory CD4 T',
#  'AGCACTGATGCTTT-1': 'DC cells',
#  'AGCACTGATTGCGA-1': 'Naive CD4 T',
#  'AGCATCGAAGATCC-1': 'Memory CD4 T',
#  'AGCATCGAAGGGTG-1': 'B-cells',
#  'AGCATCGAGCTTCC-1': 'CD14+ Mono',
#  'AGCATCGAGTGAGG-1': 'Memory CD4 T',
#  'AGCATCGATAACCG-1': 'CD14+ Mono',
#  'AGCATGACGATGAA-1': 'CD8 T',
#  'AGCCAATGGGGAGT-1': 'FCGR3A+ Mono',
#  'AGCCAATGTATCTC-1': 'Naive CD4 T',
#  'AGCCACCTGGATCT-1': 'CD8 T',
#  'AGCCGGTGCCAATG-1': 'Memory CD4 T',
#  'AGCCGGTGTGTTTC-1': 'Naive CD4 T',
#  'AGCCGTCTCAATCG-1': 'Naive CD4 T',
#  'AGCCGTCTGAGAGC-1': 'Memory CD4 T',
#  'AGCCTCACGTTCGA-1': 'Naive CD4 T',
#  'AGCCTCACTGTCAG-1': 'FCGR3A+ Mono',
#  'AGCCTCTGCAGTTG-1': 'B-cells',
#  'AGCCTCTGCCAATG-1': 'NK cells',
#  'AGCGAACTGGATCT-1': 'Naive CD4 T',
#  'AGCGAACTTACTGG-1': 'Memory CD4 T',
#  'AGCGATACGGAGCA-1': 'Naive CD4 T',
#  'AGCGATTGAGATCC-1': 'NK cells',
#  'AGCGCCGAATCTCT-1': 'Naive CD4 T',
#  'AGCGCCGACAGAGG-1': 'Memory CD4 T',
#  'AGCGCTCTACCTTT-1': 'Naive CD4 T',
#  'AGCGGCACCGGGAA-1': 'Naive CD4 T',
#  'AGCGGCTGATGTGC-1': 'Naive CD4 T',
#  'AGCGGGCTTGCCAA-1': 'Naive CD4 T',
#  'AGCGTAACATGCTG-1': 'Memory CD4 T',
#  'AGCGTAACTGAGAA-1': 'CD14+ Mono',
#  'AGCTCGCTACTGGT-1': 'Naive CD4 T',
#  'AGCTCGCTCTGCTC-1': 'Naive CD4 T',
#  'AGCTGAACCATACG-1': 'FCGR3A+ Mono',
#  'AGCTGAACCTCTCG-1': 'Naive CD4 T',
#  'AGCTGCCTTGGGAG-1': 'CD14+ Mono',
#  'AGCTGCCTTTCATC-1': 'Memory CD4 T',
#  'AGCTGCCTTTCTGT-1': 'Memory CD4 T',
#  'AGCTGTGATCCAAG-1': 'Naive CD4 T',
#  'AGCTTTACAAGTAG-1': 'Naive CD4 T',
#  'AGCTTTACACCAAC-1': 'CD8 T',
#  'AGCTTTACTCTCAT-1': 'B-cells',
#  'AGGAAATGAGGAGC-1': 'Memory CD4 T',
#  'AGGAACCTCTTAGG-1': 'FCGR3A+ Mono',
#  'AGGAACCTTGCCTC-1': 'CD8 T',
#  'AGGAATGATAACGC-1': 'Memory CD4 T',
#  'AGGAATGATTTGTC-1': 'Memory CD4 T',
#  'AGGAGTCTGGTTTG-1': 'Naive CD4 T',
#  'AGGAGTCTTGTCAG-1': 'Naive CD4 T',
#  'AGGATAGACATTTC-1': 'Memory CD4 T',
#  'AGGATAGAGGATTC-1': 'CD8 T',
#  'AGGATGCTACTAGC-1': 'B-cells',
#  'AGGATGCTTTAGGC-1': 'NK cells',
#  'AGGCAACTGAAGGC-1': 'Naive CD4 T',
#  'AGGCAGGAGTACCA-1': 'CD8 T',
#  'AGGCCTCTAGTCGT-1': 'Naive CD4 T',
#  'AGGCCTCTCGGAGA-1': 'Memory CD4 T',
#  'AGGCCTCTCGTAAC-1': 'Naive CD4 T',
#  'AGGGACGACGTTGA-1': 'Naive CD4 T',
#  'AGGGACGAGTCAAC-1': 'NK cells',
#  'AGGGACGAGTTGTG-1': 'Naive CD4 T',
#  'AGGGACGATAGAGA-1': 'CD8 T',
#  'AGGGACGATGCATG-1': 'CD8 T',
#  'AGGGAGTGAGCCTA-1': 'Naive CD4 T',
#  'AGGGCCACCATACG-1': 'Naive CD4 T',
#  'AGGGCGCTAACCAC-1': 'CD14+ Mono',
#  'AGGGCGCTATGGTC-1': 'Memory CD4 T',
#  'AGGGTGGACAGTCA-1': 'B-cells',
#  'AGGGTGGACTCAAG-1': 'CD14+ Mono',
#  'AGGGTGGAGTTGCA-1': 'CD8 T',
#  'AGGGTTTGTTCATC-1': 'CD14+ Mono',
#  'AGGTCATGAGTGTC-1': 'B-cells',
#  'AGGTCATGCTTATC-1': 'CD8 T',
#  'AGGTCTGATTCTCA-1': 'FCGR3A+ Mono',
#  'AGGTGGGAAGAATG-1': 'Memory CD4 T',
#  'AGGTGGGAAGTTCG-1': 'Naive CD4 T',
#  'AGGTGTTGGTTACG-1': 'B-cells',
#  'AGGTTCGAACCTCC-1': 'CD14+ Mono',
#  'AGGTTCGAACGTAC-1': 'CD14+ Mono',
#  'AGGTTCGAGGGTGA-1': 'Naive CD4 T',
#  'AGTAAGGAGTTTGG-1': 'Memory CD4 T',
#  'AGTAAGGATTCTTG-1': 'Memory CD4 T',
#  'AGTAATACATCACG-1': 'NK cells',
#  'AGTAATACCGAACT-1': 'B-cells',
#  'AGTAATTGTCCCAC-1': 'Memory CD4 T',
#  'AGTACGTGAGGGTG-1': 'Naive CD4 T',
#  'AGTACGTGCTGCAA-1': 'Naive CD4 T',
#  'AGTACGTGCTTGGA-1': 'Memory CD4 T',
#  'AGTACTCTACGTGT-1': 'B-cells',
#  'AGTACTCTCAACCA-1': 'CD8 T',
#  'AGTACTCTCGGTAT-1': 'Memory CD4 T',
#  'AGTAGGCTTGCCTC-1': 'FCGR3A+ Mono',
#  'AGTATAACTTGTCT-1': 'FCGR3A+ Mono',
#  'AGTATCCTAGAACA-1': 'Naive CD4 T',
#  'AGTCACGATGAGCT-1': 'NK cells',
#  'AGTCAGACGAATAG-1': 'Memory CD4 T',
#  'AGTCAGACGCTTAG-1': 'Naive CD4 T',
#  'AGTCAGACTAGAGA-1': 'CD8 T',
#  'AGTCAGACTGCACA-1': 'Memory CD4 T',
#  'AGTCCAGATATCTC-1': 'Naive CD4 T',
#  'AGTCCAGATTTCAC-1': 'Memory CD4 T',
#  'AGTCGAACCAACCA-1': 'Naive CD4 T',
#  'AGTCGCCTCCGTAA-1': 'Memory CD4 T',
#  'AGTCTACTAGGGTG-1': 'CD14+ Mono',
#  'AGTCTACTTGCATG-1': 'FCGR3A+ Mono',
#  'AGTCTTACACCACA-1': 'Naive CD4 T',
#  'AGTCTTACTTCGCC-1': 'CD8 T',
#  'AGTCTTACTTCGGA-1': 'Platelet',
#  'AGTGACTGCAACTG-1': 'FCGR3A+ Mono',
#  'AGTGTTCTAACCTG-1': 'Memory CD4 T',
#  'AGTGTTCTATAAGG-1': 'Naive CD4 T',
#  'AGTGTTCTCACTTT-1': 'CD14+ Mono',
#  'AGTTAAACCACTTT-1': 'Memory CD4 T',
#  'AGTTATGAACAGTC-1': 'CD14+ Mono',
#  'AGTTATGACTGAGT-1': 'Memory CD4 T',
#  'AGTTATGAGTTCAG-1': 'Memory CD4 T',
#  'AGTTCTACCAGCTA-1': 'CD14+ Mono',
#  'AGTTCTTGAAGCCT-1': 'CD8 T',
#  'AGTTGTCTACTACG-1': 'Naive CD4 T',
#  'AGTTTAGATGGTCA-1': 'Naive CD4 T',
#  'AGTTTCACGGTCTA-1': 'CD8 T',
#  'AGTTTGCTACAGTC-1': 'Naive CD4 T',
#  'AGTTTGCTACTGGT-1': 'CD8 T',
#  'AGTTTGCTCCAAGT-1': 'Naive CD4 T',
#  'ATAAACACAGTGCT-1': 'B-cells',
#  'ATAAACACCACCAA-1': 'Naive CD4 T',
#  'ATAACAACATGCTG-1': 'CD14+ Mono',
#  'ATAACAACGTCTAG-1': 'Naive CD4 T',
#  'ATAACAACTTTGTC-1': 'Naive CD4 T',
#  'ATAACATGTACTCT-1': 'Memory CD4 T',
#  'ATAACCCTGTTGGT-1': 'Naive CD4 T',
#  'ATAACCCTTGGTAC-1': 'Memory CD4 T',
#  'ATAAGTACGAATGA-1': 'B-cells',
#  'ATAAGTTGGTACGT-1': 'FCGR3A+ Mono',
#  'ATAAGTTGTCTAGG-1': 'Memory CD4 T',
#  'ATAATCGAGCTGAT-1': 'B-cells',
#  'ATAATCGATGGTTG-1': 'Naive CD4 T',
#  'ATAATGACCTACTT-1': 'Memory CD4 T',
#  'ATAATGACTCGTGA-1': 'CD14+ Mono',
#  'ATACAATGTTAGGC-1': 'Naive CD4 T',
#  'ATACCACTCGTACA-1': 'CD14+ Mono',
#  'ATACCACTCTAAGC-1': 'DC cells',
#  'ATACCACTGCCAAT-1': 'CD8 T',
#  'ATACCGGAATGCTG-1': 'DC cells',
#  'ATACCGGACATTTC-1': 'CD14+ Mono',
#  'ATACCGGACTTCGC-1': 'Memory CD4 T',
#  'ATACCGGAGGTGTT-1': 'CD14+ Mono',
#  'ATACCGGATCTCGC-1': 'Naive CD4 T',
#  'ATACCTACGCATCA-1': 'Memory CD4 T',
#  'ATACCTTGGGGCAA-1': 'Naive CD4 T',
#  'ATACGGACAGACTC-1': 'CD14+ Mono',
#  'ATACGGACCTACTT-1': 'CD14+ Mono',
#  'ATACGGACGAGGTG-1': 'B-cells',
#  'ATACGGACTATGCG-1': 'B-cells',
#  'ATACGGACTCTGGA-1': 'CD14+ Mono',
#  'ATACGTCTTAACGC-1': 'CD14+ Mono',
#  'ATACTCTGCTTCGC-1': 'CD14+ Mono',
#  'ATACTCTGGTATGC-1': 'NK cells',
#  'ATAGATACCATGGT-1': 'Memory CD4 T',
#  'ATAGATACGACGAG-1': 'Naive CD4 T',
#  'ATAGATTGGTGTAC-1': 'B-cells',
#  'ATAGCCGAACGGAG-1': 'Naive CD4 T',
#  'ATAGCGTGCAGATC-1': 'Memory CD4 T',
#  'ATAGCGTGCCCTTG-1': 'CD14+ Mono',
#  'ATAGCGTGGTATCG-1': 'CD14+ Mono',
#  'ATAGCGTGTCTCTA-1': 'Memory CD4 T',
#  'ATAGCTCTCTGATG-1': 'Naive CD4 T',
#  'ATAGCTCTGAGGTG-1': 'Naive CD4 T',
#  'ATAGGAGAAACAGA-1': 'CD14+ Mono',
#  'ATAGGCTGTCAGAC-1': 'Naive CD4 T',
#  'ATAGTCCTAGTGTC-1': 'CD14+ Mono',
#  'ATAGTCCTTGCATG-1': 'CD8 T',
#  'ATAGTCCTTGTCGA-1': 'Naive CD4 T',
#  'ATAGTTGACAACTG-1': 'Naive CD4 T',
#  'ATAGTTGACCCTCA-1': 'FCGR3A+ Mono',
#  'ATAGTTGAGACGTT-1': 'Naive CD4 T',
#  'ATAGTTGATAAGCC-1': 'Naive CD4 T',
#  'ATATACGAAGCCAT-1': 'Naive CD4 T',
#  'ATATACGAATTGGC-1': 'Memory CD4 T',
#  'ATATAGTGGAATGA-1': 'CD14+ Mono',
#  'ATATGCCTAGATCC-1': 'CD14+ Mono',
#  'ATATGCCTGGACAG-1': 'Memory CD4 T',
#  'ATATGCCTTCTCTA-1': 'Memory CD4 T',
#  'ATATGCCTTGGTAC-1': 'Naive CD4 T',
#  'ATCAAATGAGCCTA-1': 'CD14+ Mono',
#  'ATCAAATGGGTAAA-1': 'FCGR3A+ Mono',
#  'ATCAACCTAAACGA-1': 'Memory CD4 T',
#  'ATCAACCTGAGGAC-1': 'Naive CD4 T',
#  'ATCAACCTTCTCTA-1': 'CD8 T',
#  'ATCAACCTTTGTCT-1': 'CD8 T',
#  'ATCACACTTTGTCT-1': 'Memory CD4 T',
#  'ATCACGGATTTCGT-1': 'B-cells',
#  'ATCATCTGACACCA-1': 'Platelet',
#  'ATCATGCTAGAGTA-1': 'CD8 T',
#  'ATCATGCTGAACCT-1': 'B-cells',
#  'ATCCAGGACGCTAA-1': 'FCGR3A+ Mono',
#  'ATCCAGGATGGAAA-1': 'Memory CD4 T',
#  'ATCCATACTCCTTA-1': 'CD14+ Mono',
#  'ATCCATACTTCATC-1': 'FCGR3A+ Mono',
#  'ATCCCGTGCAGTCA-1': 'NK cells',
#  'ATCCCGTGCATGCA-1': 'B-cells',
#  'ATCCCGTGGCTGAT-1': 'B-cells',
#  'ATCCGCACGCATCA-1': 'B-cells',
#  'ATCCTAACGACGGA-1': 'B-cells',
#  'ATCCTAACGCTACA-1': 'CD8 T',
#  'ATCGACGAAACTGC-1': 'CD14+ Mono',
#  'ATCGACGAATGACC-1': 'Naive CD4 T',
#  'ATCGAGTGGACGTT-1': 'CD8 T',
#  'ATCGCAGAATCTCT-1': 'FCGR3A+ Mono',
#  'ATCGCAGAGTGTCA-1': 'B-cells',
#  'ATCGCCACTGAGGG-1': 'CD8 T',
#  'ATCGCCTGGGTCAT-1': 'Naive CD4 T',
#  'ATCGCCTGTGGCAT-1': 'B-cells',
#  'ATCGCGCTCAGAGG-1': 'CD14+ Mono',
#  'ATCGCGCTGGGATG-1': 'Memory CD4 T',
#  'ATCGCGCTTTTCGT-1': 'B-cells',
#  'ATCGGAACCAGTCA-1': 'Naive CD4 T',
#  'ATCGGTGAGTCAAC-1': 'Naive CD4 T',
#  'ATCGGTGATTGCAG-1': 'Naive CD4 T',
#  'ATCGTTTGCCTACC-1': 'CD14+ Mono',
#  'ATCGTTTGGGTACT-1': 'CD14+ Mono',
#  'ATCGTTTGTGCCAA-1': 'CD14+ Mono',
#  'ATCTACACCCGCTT-1': 'CD14+ Mono',
#  'ATCTACACCGGGAA-1': 'Memory CD4 T',
#  'ATCTCAACAGGAGC-1': 'B-cells',
#  'ATCTCAACCTCGAA-1': 'Naive CD4 T',
#  'ATCTCAACCTTGTT-1': 'CD14+ Mono',
#  'ATCTGGGAAACCAC-1': 'CD14+ Mono',
#  'ATCTGGGAAGTGTC-1': 'CD14+ Mono',
#  'ATCTGGGATTCCGC-1': 'CD8 T',
#  'ATCTGTTGAACGGG-1': 'Memory CD4 T',
#  'ATCTGTTGACCTCC-1': 'Naive CD4 T',
#  'ATCTGTTGCCTTCG-1': 'FCGR3A+ Mono',
#  'ATCTGTTGGTTGCA-1': 'Memory CD4 T',
#  'ATCTTGACACCAAC-1': 'Memory CD4 T',
#  'ATCTTGACCTCCCA-1': 'CD14+ Mono',
#  'ATCTTTCTGCATCA-1': 'Naive CD4 T',
#  'ATCTTTCTGTTTCT-1': 'CD8 T',
#  'ATCTTTCTTGTCCC-1': 'NK cells',
#  'ATGAAACTCTGTGA-1': 'Memory CD4 T',
#  'ATGAAACTGAGGCA-1': 'Naive CD4 T',
#  'ATGAAGGAACAGCT-1': 'CD8 T',
#  'ATGAAGGACCTGTC-1': 'B-cells',
#  'ATGAAGGACCTTAT-1': 'B-cells',
#  'ATGAAGGACTAGTG-1': 'B-cells',
#  'ATGAAGGACTTGCC-1': 'NK cells',
#  'ATGACGTGACGACT-1': 'B-cells',
#  'ATGACGTGATCGGT-1': 'FCGR3A+ Mono',
#  'ATGAGAGAAAGTGA-1': 'Memory CD4 T',
#  'ATGAGAGAACGCAT-1': 'Naive CD4 T',
#  'ATGAGAGAAGTAGA-1': 'B-cells',
#  'ATGAGCACACAGCT-1': 'Naive CD4 T',
#  'ATGAGCACATCTTC-1': 'Naive CD4 T',
#  'ATGATAACTTCACT-1': 'NK cells',
#  'ATGATATGAAACAG-1': 'Memory CD4 T',
#  'ATGATATGACTGGT-1': 'Naive CD4 T',
#  'ATGATATGAGCACT-1': 'Naive CD4 T',
#  'ATGATATGGTCATG-1': 'Naive CD4 T',
#  'ATGATATGGTGCTA-1': 'NK cells',
#  'ATGATATGTTGTCT-1': 'CD14+ Mono',
#  'ATGCACGAATGTCG-1': 'B-cells',
#  'ATGCACGACTGTAG-1': 'Naive CD4 T',
#  'ATGCACGAGAACCT-1': 'B-cells',
#  'ATGCACGAGTTCGA-1': 'Naive CD4 T',
#  'ATGCACGATTGGTG-1': 'CD14+ Mono',
#  'ATGCAGTGTTACCT-1': 'B-cells',
#  'ATGCAGTGTTCTAC-1': 'Memory CD4 T',
#  'ATGCCAGAACGACT-1': 'Naive CD4 T',
#  'ATGCCAGACAGTCA-1': 'CD14+ Mono',
#  'ATGCCGCTTGAACC-1': 'CD14+ Mono',
#  'ATGCGATGCTATGG-1': 'CD14+ Mono',
#  'ATGCGATGCTGAGT-1': 'Naive CD4 T',
#  'ATGCGATGGTTACG-1': 'B-cells',
#  'ATGCGCCTTCATTC-1': 'Naive CD4 T',
#  'ATGCTTTGCGAATC-1': 'Memory CD4 T',
#  'ATGCTTTGGGCGAA-1': 'CD8 T',
#  'ATGCTTTGTAGTCG-1': 'B-cells',
#  'ATGGACACATCGGT-1': 'Memory CD4 T',
#  'ATGGACACGCATCA-1': 'NK cells',
#  'ATGGGTACAACCTG-1': 'B-cells',
#  'ATGGGTACATCGGT-1': 'NK cells',
#  'ATGGGTACTATTCC-1': 'Memory CD4 T',
#  'ATGGGTACTGGGAG-1': 'Memory CD4 T',
#  'ATGTAAACACCTCC-1': 'Naive CD4 T',
#  'ATGTAAACCCGCTT-1': 'Memory CD4 T',
#  'ATGTAAACGGGATG-1': 'DC cells',
#  'ATGTAAACTCTCCG-1': 'Memory CD4 T',
#  'ATGTAAACTTCACT-1': 'CD14+ Mono',
#  'ATGTACCTCAGTCA-1': 'Naive CD4 T',
#  'ATGTACCTTAGTCG-1': 'Memory CD4 T',
#  'ATGTACCTTTATCC-1': 'CD14+ Mono',
#  'ATGTACCTTTCACT-1': 'CD8 T',
#  'ATGTCACTAATGCC-1': 'CD14+ Mono',
#  'ATGTCACTCTGCTC-1': 'Naive CD4 T',
#  'ATGTCGGAGGTGAG-1': 'Memory CD4 T',
#  'ATGTTCACAGTCTG-1': 'CD14+ Mono',
#  'ATGTTCACCGTAGT-1': 'Memory CD4 T',
#  'ATGTTGCTTTCAGG-1': 'Memory CD4 T',
#  'ATTAACGATGAGAA-1': 'NK cells',
#  'ATTAACGATGCAAC-1': 'CD8 T',
#  'ATTAAGACTGCAGT-1': 'Memory CD4 T',
#  'ATTACCTGCCTTAT-1': 'CD14+ Mono',
#  'ATTACCTGGAGGAC-1': 'FCGR3A+ Mono',
#  'ATTAGATGTTTCAC-1': 'Naive CD4 T',
#  'ATTATGGAATCTCT-1': 'Memory CD4 T',
#  'ATTCAAGAACGGGA-1': 'Naive CD4 T',
#  'ATTCAAGACCTTTA-1': 'Memory CD4 T',
#  'ATTCAGCTCATTGG-1': 'Platelet',
#  'ATTCCAACCATTGG-1': 'CD14+ Mono',
#  'ATTCCAACTTAGGC-1': 'NK cells',
#  'ATTCGACTCACTAG-1': 'CD8 T',
#  'ATTCGACTGAATAG-1': 'CD14+ Mono',
#  'ATTCGACTTTTGTC-1': 'FCGR3A+ Mono',
#  'ATTCGGGAAAGGCG-1': 'CD14+ Mono',
#  'ATTCGGGATTAGGC-1': 'Memory CD4 T',
#  'ATTCTTCTGATACC-1': 'CD8 T',
#  'ATTGAATGGACGGA-1': 'Naive CD4 T',
#  'ATTGATGAAGGTTC-1': 'Naive CD4 T',
#  'ATTGATGACTGAGT-1': 'Naive CD4 T',
#  'ATTGATGAGCGAAG-1': 'Memory CD4 T',
#  'ATTGATGATCTATC-1': 'Naive CD4 T',
#  'ATTGCACTGACGGA-1': 'Naive CD4 T',
#  'ATTGCACTGAGAGC-1': 'FCGR3A+ Mono',
#  'ATTGCACTGGAGCA-1': 'CD14+ Mono',
#  'ATTGCACTTAGCCA-1': 'Memory CD4 T',
#  'ATTGCACTTGCTTT-1': 'FCGR3A+ Mono',
#  'ATTGCTTGTTACTC-1': 'B-cells',
#  'ATTGGTCTGACTAC-1': 'B-cells',
#  'ATTGGTCTTGTCTT-1': 'B-cells',
#  'ATTGTAGATTCCCG-1': 'DC cells',
#  'ATTGTAGATTGCAG-1': 'Naive CD4 T',
#  'ATTGTCTGCGTACA-1': 'Memory CD4 T',
#  'ATTTAGGAACCATG-1': 'FCGR3A+ Mono',
#  'ATTTAGGACAGAGG-1': 'Memory CD4 T',
#  'ATTTCCGAGATGAA-1': 'Memory CD4 T',
#  'ATTTCCGAGTGCTA-1': 'Memory CD4 T',
#  'ATTTCGTGTATGGC-1': 'CD8 T',
#  'ATTTCTCTACTTTC-1': 'FCGR3A+ Mono',
#  'ATTTCTCTAGCAAA-1': 'Memory CD4 T',
#  'ATTTCTCTCACTTT-1': 'FCGR3A+ Mono',
#  'ATTTCTCTTCCCAC-1': 'Naive CD4 T',
#  'ATTTGCACAAGATG-1': 'CD14+ Mono',
#  'CAAAGCACAGCTCA-1': 'Naive CD4 T',
#  'CAAAGCACCGTAAC-1': 'B-cells',
#  'CAAAGCACGGTAAA-1': 'CD8 T',
#  'CAAAGCTGAAAGTG-1': 'Naive CD4 T',
#  'CAAAGCTGTTGCTT-1': 'CD14+ Mono',
#  'CAAATATGTGACAC-1': 'Naive CD4 T',
#  'CAAATTGAGGGCAA-1': 'Naive CD4 T',
#  'CAAATTGATGGAGG-1': 'CD14+ Mono',
#  'CAACCAGAAAAGTG-1': 'Naive CD4 T',
#  'CAACCAGAAGTGCT-1': 'Memory CD4 T',
#  'CAACCAGAGTTCAG-1': 'CD14+ Mono',
#  'CAACCAGATAGAAG-1': 'CD14+ Mono',
#  'CAACCGCTGTTCAG-1': 'Naive CD4 T',
#  'CAACCGCTTTGAGC-1': 'Memory CD4 T',
#  'CAACGATGCGCAAT-1': 'CD14+ Mono',
#  'CAACGTGACTCCAC-1': 'CD14+ Mono',
#  'CAACGTGAGCCATA-1': 'CD8 T',
#  'CAACGTGATCAAGC-1': 'CD14+ Mono',
#  'CAAGAAGACCACAA-1': 'CD8 T',
#  'CAAGAAGACGTCTC-1': 'CD14+ Mono',
#  'CAAGAAGATTCTAC-1': 'Naive CD4 T',
#  'CAAGACTGACCTGA-1': 'B-cells',
#  'CAAGACTGAGTAGA-1': 'B-cells',
#  'CAAGCTGACCATAG-1': 'FCGR3A+ Mono',
#  'CAAGCTGATCTATC-1': 'CD8 T',
#  'CAAGGACTGTTCAG-1': 'Naive CD4 T',
#  'CAAGGACTTCTTTG-1': 'CD8 T',
#  'CAAGGTTGCTCCAC-1': 'Memory CD4 T',
#  'CAAGGTTGTCATTC-1': 'B-cells',
#  'CAAGGTTGTCTGGA-1': 'NK cells',
#  'CAAGTCGAAACAGA-1': 'B-cells',
#  'CAAGTCGATAGCGT-1': 'CD14+ Mono',
#  'CAATAAACGCCATA-1': 'CD14+ Mono',
#  'CAATAATGAACTGC-1': 'CD14+ Mono',
#  'CAATATGACATGGT-1': 'Memory CD4 T',
#  'CAATATGACCTTCG-1': 'CD8 T',
#  'CAATATGACGTTAG-1': 'Naive CD4 T',
#  'CAATATGAGGAGCA-1': 'Naive CD4 T',
#  'CAATCGGAGAAACA-1': 'Naive CD4 T',
#  'CAATCTACTGACTG-1': 'NK cells',
#  'CAATTCACCCAACA-1': 'CD8 T',
#  'CAATTCACGATAGA-1': 'Naive CD4 T',
#  'CAATTCACTTGTGG-1': 'Naive CD4 T',
#  'CAATTCTGCTTGTT-1': 'CD14+ Mono',
#  'CAATTCTGGCGTAT-1': 'FCGR3A+ Mono',
#  'CACAACGATACGAC-1': 'Naive CD4 T',
#  'CACAATCTTGTTCT-1': 'CD8 T',
#  'CACAATCTTTCCAT-1': 'Memory CD4 T',
#  'CACACCTGCTTGAG-1': 'Naive CD4 T',
#  'CACACCTGTATGGC-1': 'Naive CD4 T',
#  'CACAGAACCCTTGC-1': 'B-cells',
#  'CACAGAACCTGATG-1': 'Memory CD4 T',
#  'CACAGATGGGATTC-1': 'Memory CD4 T',
#  'CACAGATGGTTTCT-1': 'CD14+ Mono',
#  'CACAGCCTGATACC-1': 'CD8 T',
#  'CACAGCCTTGCCAA-1': 'FCGR3A+ Mono',
#  'CACAGCCTTGTAGC-1': 'Naive CD4 T',
#  'CACAGTGATGAAGA-1': 'CD14+ Mono',
#  'CACATACTACAGCT-1': 'CD8 T',
#  'CACATGGAACACGT-1': 'Naive CD4 T',
#  'CACATGGAAGTCGT-1': 'Naive CD4 T',
#  'CACCACTGCCAACA-1': 'Naive CD4 T',
#  'CACCACTGGCGAAG-1': 'CD8 T',
#  'CACCCATGTTCTGT-1': 'Naive CD4 T',
#  'CACCGGGAATCGAC-1': 'Memory CD4 T',
#  'CACCGGGACGAGAG-1': 'CD8 T',
#  'CACCGGGACGTGTA-1': 'Naive CD4 T',
#  'CACCGGGACTTCTA-1': 'Memory CD4 T',
#  'CACCGGGACTTGCC-1': 'CD8 T',
#  'CACCGGGATTCGGA-1': 'CD8 T',
#  'CACCGTACTAAGGA-1': 'B-cells',
#  'CACCGTACTAGCGT-1': 'Naive CD4 T',
#  'CACCTGACACCCAA-1': 'CD8 T',
#  'CACCTGACCAGAAA-1': 'Memory CD4 T',
#  'CACCTGACCTCAAG-1': 'CD8 T',
#  'CACCTGACGAAAGT-1': 'B-cells',
#  'CACCTGACTCGTAG-1': 'Naive CD4 T',
#  'CACGAAACTTCCGC-1': 'B-cells',
#  'CACGACCTCGATAC-1': 'B-cells',
#  'CACGCTACAGAAGT-1': 'Naive CD4 T',
#  'CACGCTACTGTTCT-1': 'B-cells',
#  'CACGGGACAGAGTA-1': 'Naive CD4 T',
#  'CACGGGACATAAGG-1': 'Naive CD4 T',
#  'CACGGGACGTAGGG-1': 'Memory CD4 T',
#  'CACGGGTGCTTCGC-1': 'CD8 T',
#  'CACGGGTGGAGGAC-1': 'CD8 T',
#  'CACGGGTGTGTTTC-1': 'Naive CD4 T',
#  'CACTAACTCCTAAG-1': 'B-cells',
#  'CACTAACTGAAAGT-1': 'Naive CD4 T',
#  'CACTAGGATGATGC-1': 'B-cells',
#  'CACTATACCCCGTT-1': 'B-cells',
#  'CACTATACGTTTGG-1': 'CD8 T',
#  'CACTGAGACAGTCA-1': 'CD14+ Mono',
#  'CACTGCACTTCATC-1': 'Memory CD4 T',
#  'CACTGCTGAGACTC-1': 'FCGR3A+ Mono',
#  'CACTGCTGGAAAGT-1': 'Memory CD4 T',
#  'CACTTAACCGAATC-1': 'Memory CD4 T',
#  'CACTTAACCGTACA-1': 'B-cells',
#  'CACTTTGACTCTAT-1': 'CD8 T',
#  'CACTTTGAGCTGTA-1': 'Naive CD4 T',
#  'CAGAAGCTCTCAAG-1': 'Naive CD4 T',
#  'CAGACATGAACGGG-1': 'Naive CD4 T',
#  'CAGACATGTCGACA-1': 'Memory CD4 T',
#  'CAGACCCTAAGGTA-1': 'FCGR3A+ Mono',
#  'CAGACCCTAATGCC-1': 'Naive CD4 T',
#  'CAGACCCTAGGAGC-1': 'Memory CD4 T',
#  'CAGACTGAGTATGC-1': 'Naive CD4 T',
#  'CAGATCGAATGTCG-1': 'B-cells',
#  'CAGATCGACCTGAA-1': 'CD8 T',
#  'CAGATCGATATGGC-1': 'Memory CD4 T',
#  'CAGATGACATTCTC-1': 'NK cells',
#  'CAGCAATGCCTTCG-1': 'Naive CD4 T',
#  'CAGCAATGGAGGGT-1': 'NK cells',
#  'CAGCAATGGTGCTA-1': 'Naive CD4 T',
#  'CAGCAATGTCTACT-1': 'CD14+ Mono',
#  'CAGCAATGTGACCA-1': 'Memory CD4 T',
#  'CAGCAATGTGAGGG-1': 'CD14+ Mono',
#  'CAGCACCTAAGCCT-1': 'Naive CD4 T',
#  'CAGCACCTAGGCGA-1': 'Naive CD4 T',
#  'CAGCACCTGTAGGG-1': 'CD14+ Mono',
#  'CAGCATGACAACCA-1': 'CD14+ Mono',
#  'CAGCATGAGACGTT-1': 'CD8 T',
#  'CAGCCTACCCAACA-1': 'Memory CD4 T',
#  'CAGCCTTGCTACCC-1': 'CD14+ Mono',
#  'CAGCCTTGGGGACA-1': 'Memory CD4 T',
#  'CAGCGGACACCCTC-1': 'Naive CD4 T',
#  'CAGCGGACCTTTAC-1': 'NK cells',
#  'CAGCGTCTAAAGCA-1': 'Memory CD4 T',
#  'CAGCGTCTTATCGG-1': 'Memory CD4 T',
#  'CAGCTAGATGTGAC-1': 'CD14+ Mono',
#  'CAGCTCTGAGGCGA-1': 'Memory CD4 T',
#  'CAGCTCTGCAAGCT-1': 'CD8 T',
#  'CAGCTCTGTCGTAG-1': 'CD14+ Mono',
#  'CAGCTCTGTGTGGT-1': 'NK cells',
#  'CAGGAACTAACTGC-1': 'CD8 T',
#  'CAGGAACTCTCAGA-1': 'CD14+ Mono',
#  'CAGGCCGAACACCA-1': 'Naive CD4 T',
#  'CAGGCCGAACACGT-1': 'Memory CD4 T',
#  'CAGGCCGAACGACT-1': 'Naive CD4 T',
#  'CAGGCCGAATCTCT-1': 'FCGR3A+ Mono',
#  'CAGGCCGACTAGCA-1': 'B-cells',
#  'CAGGGCACCATACG-1': 'B-cells',
#  'CAGGGCACCCAACA-1': 'Naive CD4 T',
#  'CAGGGCACTCCCGT-1': 'Memory CD4 T',
#  'CAGGTAACAGACTC-1': 'CD14+ Mono',
#  'CAGGTATGAGTCGT-1': 'Naive CD4 T',
#  'CAGGTATGTGCTTT-1': 'Memory CD4 T',
#  'CAGGTTGAGGATCT-1': 'B-cells',
#  'CAGTGATGGACGGA-1': 'B-cells',
#  'CAGTGATGGCTAAC-1': 'CD8 T',
#  'CAGTGATGGGACAG-1': 'Memory CD4 T',
#  'CAGTGATGTAAGGA-1': 'B-cells',
#  'CAGTGATGTACGCA-1': 'B-cells',
#  'CAGTGTGATGTCAG-1': 'Naive CD4 T',
#  'CAGTTACTAAGGTA-1': 'B-cells',
#  'CAGTTACTGATAGA-1': 'Memory CD4 T',
#  'CAGTTGGAAAGAGT-1': 'CD14+ Mono',
#  'CAGTTGGACATACG-1': 'Naive CD4 T',
#  'CAGTTTACACACGT-1': 'NK cells',
#  'CAGTTTACCCCAAA-1': 'Naive CD4 T',
#  'CATAAAACGGAGCA-1': 'CD14+ Mono',
#  'CATAAATGAACTGC-1': 'Naive CD4 T',
#  'CATAACCTTCTCCG-1': 'Memory CD4 T',
#  'CATACTACCTCGAA-1': 'Naive CD4 T',
#  'CATACTACCTGAAC-1': 'Naive CD4 T',
#  'CATACTACGTACCA-1': 'CD14+ Mono',
#  'CATACTTGGGTTAC-1': 'FCGR3A+ Mono',
#  'CATAGTCTAATCGC-1': 'Naive CD4 T',
#  'CATAGTCTCACTTT-1': 'Naive CD4 T',
#  'CATATAGACTAAGC-1': 'DC cells',
#  'CATATAGATCAGGT-1': 'B-cells',
#  'CATCAACTAGAAGT-1': 'Memory CD4 T',
#  'CATCAACTCCCTCA-1': 'Naive CD4 T',
#  'CATCAGGACTTCCG-1': 'NK cells',
#  'CATCAGGATAGCCA-1': 'NK cells',
#  'CATCAGGATCCTAT-1': 'FCGR3A+ Mono',
#  'CATCAGGATGCACA-1': 'CD14+ Mono',
#  'CATCAGGATTTCGT-1': 'CD14+ Mono',
#  'CATCATACCGCATA-1': 'CD14+ Mono',
#  'CATCATACGGAGCA-1': 'B-cells',
#  'CATCATACTCAAGC-1': 'Naive CD4 T',
#  'CATCGCTGGGATCT-1': 'Memory CD4 T',
#  'CATCGCTGTGGCAT-1': 'B-cells',
#  'CATCGGCTATGCTG-1': 'Memory CD4 T',
#  'CATCGGCTTTGGCA-1': 'Memory CD4 T',
#  'CATCTCCTATGTGC-1': 'B-cells',
#  'CATCTCCTCGAACT-1': 'CD14+ Mono',
#  'CATGAGACACGGGA-1': 'B-cells',
#  'CATGAGACGTTGAC-1': 'NK cells',
#  'CATGAGACTCGCCT-1': 'Naive CD4 T',
#  'CATGCCACGGGTGA-1': 'Naive CD4 T',
#  'CATGCCACTGCCAA-1': 'Memory CD4 T',
#  'CATGCGCTAGTCAC-1': 'FCGR3A+ Mono',
#  'CATGCGCTCAGATC-1': 'CD14+ Mono',
#  'CATGCGCTTTGCAG-1': 'FCGR3A+ Mono',
#  'CATGGCCTAGGGTG-1': 'CD14+ Mono',
#  'CATGGCCTGTGCAT-1': 'Naive CD4 T',
#  'CATGTACTATCGTG-1': 'CD8 T',
#  'CATGTTACAGTCGT-1': 'CD8 T',
#  'CATGTTACCTGAGT-1': 'Memory CD4 T',
#  'CATGTTTGGGGATG-1': 'CD14+ Mono',
#  'CATTACACACGGAG-1': 'B-cells',
#  'CATTACACCAACTG-1': 'NK cells',
#  'CATTACACGGAGTG-1': 'Naive CD4 T',
#  'CATTACACTACTCT-1': 'Naive CD4 T',
#  'CATTAGCTCCACAA-1': 'CD14+ Mono',
#  'CATTGACTAGCGGA-1': 'CD14+ Mono',
#  'CATTGGGACTCGAA-1': 'Naive CD4 T',
#  'CATTGTACAGCGTT-1': 'Naive CD4 T',
#  'CATTGTACTCGATG-1': 'B-cells',
#  'CATTGTACTTATCC-1': 'Naive CD4 T',
#  'CATTGTACTTTGCT-1': 'FCGR3A+ Mono',
#  'CATTGTTGCTAGTG-1': 'Naive CD4 T',
#  'CATTTCGACTCTAT-1': 'CD8 T',
#  'CATTTCGAGATACC-1': 'NK cells',
#  'CATTTGACCACACA-1': 'CD8 T',
#  'CATTTGACCCTGAA-1': 'CD8 T',
#  'CATTTGTGACGACT-1': 'B-cells',
#  'CATTTGTGCATTGG-1': 'Naive CD4 T',
#  'CATTTGTGCGGAGA-1': 'Naive CD4 T',
#  'CATTTGTGGGATCT-1': 'B-cells',
#  ...}

# %%
# Show cell names
cell_names.head()
# Out:
# 0    AAACATACAACCAC-1
# 1    AAACATTGAGCTAC-1
# 2    AAACATTGATCAGC-1
# 3    AAACCGTGCTTCCG-1
# 4    AAACCGTGTATGCG-1
# Name: 0, dtype: object

# %%
# Show gene names
gene_names.head(10)

# %%
# Load expression matrix
expression_mtx = mmread(data_path)

# %%
# Show shapes
print('Expression shape : {}'.format(expression_mtx.shape))
print('Num cells : {}'.format(cell_names.shape[0]))
print('Num genes : {}'.format(gene_names.shape[0]))
# Out:
# Expression shape : (32738, 2700)
# Num cells : 2700
# Num genes : 32738

# %%
# Create dataframe from sparse matrix
expression_df = pd.DataFrame.sparse.from_spmatrix(
    expression_mtx,
    columns=cell_names.to_numpy(),
    index=gene_names.to_numpy()
)

# %%
expression_df.iloc[1300:1320, 1100:1120]
# Out:
#                CCGCTATGTGCAAC-1  CCGCTATGTGCACA-1  CCGGTACTGTCCTC-1  \
# RP11-131L23.2               0.0               0.0               0.0
# RP11-290M5.4                0.0               0.0               0.0
# CYR61                       0.0               0.0               0.0
# RP11-290M5.2                0.0               0.0               0.0
# ZNHIT6                      0.0               0.0               0.0
# COL24A1                     0.0               0.0               0.0
# ODF2L                       0.0               0.0               0.0
# CLCA2                       0.0               0.0               0.0
# CLCA1                       0.0               0.0               0.0
# CLCA4                       0.0               0.0               0.0
# RP4-651E10.4                0.0               0.0               0.0
# RP4-612B15.3                0.0               0.0               0.0
# SH3GLB1                     2.0               0.0               0.0
# SEP15                       1.0               0.0               0.0
# HS2ST1                      0.0               0.0               0.0
# RP4-604K5.3                 0.0               0.0               0.0
# RP4-604K5.2                 0.0               0.0               0.0
# RP5-1052I5.2                0.0               0.0               0.0
# LINC01140                   0.0               0.0               0.0
# LMO4                        0.0               0.0               0.0
#
#                CCGTACACAAGCAA-1  CCGTACACAGCGTT-1  CCGTACACGTCATG-1  \
# RP11-131L23.2               0.0               0.0               0.0
# RP11-290M5.4                0.0               0.0               0.0
# CYR61                       0.0               0.0               0.0
# RP11-290M5.2                0.0               0.0               0.0
# ZNHIT6                      0.0               0.0               0.0
# COL24A1                     0.0               0.0               0.0
# ODF2L                       1.0               0.0               0.0
# CLCA2                       0.0               0.0               0.0
# CLCA1                       0.0               0.0               0.0
# CLCA4                       0.0               0.0               0.0
# RP4-651E10.4                0.0               0.0               0.0
# RP4-612B15.3                0.0               0.0               0.0
# SH3GLB1                     0.0               0.0               0.0
# SEP15                       1.0               1.0               0.0
# HS2ST1                      0.0               0.0               0.0
# RP4-604K5.3                 0.0               0.0               0.0
# RP4-604K5.2                 0.0               0.0               0.0
# RP5-1052I5.2                0.0               0.0               0.0
# LINC01140                   0.0               0.0               0.0
# LMO4                        1.0               0.0               0.0
#
#                CCGTACACGTTGGT-1  CCGTACACTAACGC-1  CCTAAACTTTCGTT-1  \
# RP11-131L23.2               0.0               0.0               0.0
# RP11-290M5.4                0.0               0.0               0.0
# CYR61                       0.0               0.0               0.0
# RP11-290M5.2                0.0               0.0               0.0
# ZNHIT6                      0.0               0.0               0.0
# COL24A1                     0.0               0.0               0.0
# ODF2L                       0.0               0.0               1.0
# CLCA2                       0.0               0.0               0.0
# CLCA1                       0.0               0.0               0.0
# CLCA4                       0.0               0.0               0.0
# RP4-651E10.4                0.0               0.0               0.0
# RP4-612B15.3                0.0               0.0               0.0
# SH3GLB1                     1.0               0.0               0.0
# SEP15                       1.0               0.0               1.0
# HS2ST1                      0.0               0.0               0.0
# RP4-604K5.3                 0.0               0.0               0.0
# RP4-604K5.2                 0.0               0.0               0.0
# RP5-1052I5.2                0.0               0.0               0.0
# LINC01140                   0.0               0.0               0.0
# LMO4                        0.0               0.0               0.0
#
#                CCTAAGGACCCAAA-1  CCTAAGGACTAGCA-1  CCTAAGGAGGGCAA-1  \
# RP11-131L23.2               0.0               0.0               0.0
# RP11-290M5.4                0.0               0.0               0.0
# CYR61                       0.0               0.0               0.0
# RP11-290M5.2                0.0               0.0               0.0
# ZNHIT6                      0.0               0.0               0.0
# COL24A1                     0.0               0.0               0.0
# ODF2L                       0.0               0.0               0.0
# CLCA2                       0.0               0.0               0.0
# CLCA1                       0.0               0.0               0.0
# CLCA4                       0.0               0.0               0.0
# RP4-651E10.4                0.0               0.0               0.0
# RP4-612B15.3                0.0               0.0               0.0
# SH3GLB1                     0.0               1.0               0.0
# SEP15                       1.0               0.0               0.0
# HS2ST1                      0.0               0.0               0.0
# RP4-604K5.3                 0.0               0.0               0.0
# RP4-604K5.2                 0.0               0.0               0.0
# RP5-1052I5.2                0.0               0.0               0.0
# LINC01140                   0.0               0.0               0.0
# LMO4                        0.0               0.0               0.0
#
#                CCTAAGGATGATGC-1  CCTAAGGATGTCAG-1  CCTACCGACTCTTA-1  \
# RP11-131L23.2               0.0               0.0               0.0
# RP11-290M5.4                0.0               0.0               0.0
# CYR61                       0.0               0.0               0.0
# RP11-290M5.2                0.0               0.0               0.0
# ZNHIT6                      0.0               0.0               0.0
# COL24A1                     0.0               0.0               0.0
# ODF2L                       0.0               0.0               0.0
# CLCA2                       0.0               0.0               0.0
# CLCA1                       0.0               0.0               0.0
# CLCA4                       0.0               0.0               0.0
# RP4-651E10.4                0.0               0.0               0.0
# RP4-612B15.3                0.0               0.0               0.0
# SH3GLB1                     0.0               0.0               0.0
# SEP15                       0.0               1.0               0.0
# HS2ST1                      0.0               0.0               0.0
# RP4-604K5.3                 0.0               0.0               0.0
# RP4-604K5.2                 0.0               0.0               0.0
# RP5-1052I5.2                0.0               0.0               0.0
# LINC01140                   0.0               0.0               0.0
# LMO4                        0.0               0.0               0.0
#
#                CCTACCGAGGGATG-1  CCTAGAGAGGTGAG-1  CCTATAACCAAAGA-1  \
# RP11-131L23.2               0.0               0.0               0.0
# RP11-290M5.4                0.0               0.0               0.0
# CYR61                       0.0               0.0               0.0
# RP11-290M5.2                0.0               0.0               0.0
# ZNHIT6                      0.0               0.0               0.0
# COL24A1                     0.0               0.0               0.0
# ODF2L                       0.0               0.0               1.0
# CLCA2                       0.0               0.0               0.0
# CLCA1                       0.0               0.0               0.0
# CLCA4                       0.0               0.0               0.0
# RP4-651E10.4                0.0               0.0               0.0
# RP4-612B15.3                0.0               0.0               0.0
# SH3GLB1                     0.0               0.0               0.0
# SEP15                       0.0               0.0               0.0
# HS2ST1                      0.0               0.0               0.0
# RP4-604K5.3                 0.0               0.0               0.0
# RP4-604K5.2                 0.0               0.0               0.0
# RP5-1052I5.2                0.0               0.0               0.0
# LINC01140                   0.0               0.0               0.0
# LMO4                        0.0               0.0               0.0
#
#                CCTATAACGAGACG-1  CCTATAACTCAGAC-1
# RP11-131L23.2               0.0               0.0
# RP11-290M5.4                0.0               0.0
# CYR61                       0.0               0.0
# RP11-290M5.2                0.0               0.0
# ZNHIT6                      0.0               0.0
# COL24A1                     0.0               0.0
# ODF2L                       0.0               0.0
# CLCA2                       0.0               0.0
# CLCA1                       0.0               0.0
# CLCA4                       0.0               0.0
# RP4-651E10.4                0.0               0.0
# RP4-612B15.3                0.0               0.0
# SH3GLB1                     0.0               0.0
# SEP15                       0.0               0.0
# HS2ST1                      0.0               0.0
# RP4-604K5.3                 0.0               0.0
# RP4-604K5.2                 0.0               0.0
# RP5-1052I5.2                0.0               0.0
# LINC01140                   0.0               0.0
# LMO4                        0.0               0.0

# %% [markdown]
# ## Quality controll

# %%
# Get count sum for all genes/cels
gene_sum = expression_df.sum(axis=1)
cell_sum = expression_df.sum(axis=0)

# Remove all genes that are not expressed
expression_df = expression_df.loc[
    gene_sum[gene_sum>3].index,
    cell_sum[cell_sum>10].index
].sparse.to_dense().T

# %%
expression_df.shape
# Out:
# (2700, 13164)

# %%
# Detect mitohondrial genes
mito_genes = [gene for gene in expression_df.columns if gene.startswith('MT-')]
mito_df = expression_df.loc[:, mito_genes]

# Calculate values that will be QC-ed
mito_df_sum = mito_df.sum(axis=1)
expression_df_sum = expression_df.sum(axis=1)
expression_df_num_genes = (expression_df>0).sum(axis=1)

percent_mt = mito_df_sum/expression_df_sum*100

# %%
# Function for median deviation calculation
def mad_qc(data, limit='upper'):

    # Calculate the median of the data
    median = np.median(data)

    # Calculate the absolute deviations from the median
    absolute_deviations = np.abs(data - median)

    # Calculate the median absolute deviation
    mad = np.median(absolute_deviations)

    if limit == 'upper':

        upper_limit = median + 3*mad
        return data > upper_limit

    elif limit =='lower':

        lower_limit = median - 3*mad
        return data < lower_limit

    else:
        raise Exception('Incorrect choice for limit')

# %%
# Perform QC based on three criteria
mito_qc = mad_qc(percent_mt, limit='upper')
expression_sum_qc = mad_qc(expression_df_sum, limit='lower')
num_genes_qc = mad_qc(expression_df_num_genes, limit='lower')

final_qc = mito_qc | expression_sum_qc | num_genes_qc

# %%
final_qc
# Out:
# AAACATACAACCAC-1    False
# AAACATTGAGCTAC-1     True
# AAACATTGATCAGC-1    False
# AAACCGTGCTTCCG-1    False
# AAACCGTGTATGCG-1    False
#                     ...
# TTTCGAACTCTCAT-1    False
# TTTCTACTGAGGCA-1    False
# TTTCTACTTCCTCG-1    False
# TTTGCATGAGAGGC-1    False
# TTTGCATGCCTCAC-1    False
# Length: 2700, dtype: bool

# %%
# Concatenate all QC data and QC results into
# a single dataframe
qc_df = pd.concat(
    [
        percent_mt.to_frame(name='mito'),
        expression_df_sum.to_frame(name='expr_sum'),
        expression_df_num_genes.to_frame(name='num_genes'),
        mito_qc.to_frame(name='mito_remove'),
        expression_sum_qc.to_frame(name='expr_sum_remove'),
        num_genes_qc.to_frame(name='num_genes_remove')
    ],
    axis=1
)

# Plot results
sns.catplot(qc_df, y='mito',hue='mito_remove').set(title='Mito QC')
sns.catplot(qc_df, y='expr_sum',hue='expr_sum_remove').set(title='Count sum QC')
sns.catplot(qc_df, y='num_genes',hue='num_genes_remove').set(title='Num genes QC')

# %%
# Print number of eliminated and retained cells (data points)
final_qc.value_counts()
# Out:
# False    2411
# True      289
# Name: count, dtype: int64

# %%
# Drop low quality cells
expression_df = expression_df.drop(
    index=final_qc[final_qc==True].index,
    errors='ignore'
)

# %%
# Remove cells without labels
cells_with_no_label = set(expression_df.index) - set(cell_type_dict.keys())
expression_df = expression_df.drop(index=cells_with_no_label)

# %% [markdown]
# ### Normalization

# %%
# Normalize expression of all genes in each cell by using sum of gene expressions in
# each cell
expression_df = expression_df.div(
    expression_df_sum[expression_df.index],
    axis=0
)*10000

# %%
gene_mean = expression_df.mean(axis=0)
gene_var =  expression_df.var(axis=0)

plt.scatter(gene_mean.to_numpy(), gene_var.to_numpy())
plt.title('Mean vs variance')
plt.xlabel('Mean')
plt.ylabel('Variance')
# Out:
# Text(0, 0.5, 'Variance')

# %%
expression_df['S100A4'].hist(bins=100)
plt.ylim([0,250])
plt.title('Gene S100A4 raw')
plt.xlabel('Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Log normalize the data
expression_df = np.log(expression_df + 1)

full_expression_df = expression_df.copy()

# %%
gene_mean = expression_df.mean(axis=0)
gene_var =  expression_df.var(axis=0)


plt.scatter(gene_mean.to_numpy(), gene_var.to_numpy())
plt.title('Log - Mean vs variance')
plt.xlabel('Log - Mean')
plt.ylabel('Log - Variance')
# Out:
# Text(0, 0.5, 'Log - Variance')

# %%
expression_df['S100A4'].hist(bins=100)
plt.ylim([0,250])
plt.title('Log - Gene S100A4 raw')
plt.xlabel('Log - Value')
plt.ylabel('Log - Count')
# Out:
# Text(0, 0.5, 'Log - Count')

# %% [markdown]
# ### Feature selection

# %%
# Add everything to data frame
gene_df = pd.concat([gene_mean, gene_var], axis=1)
gene_df.columns = ['mean', 'var']

# Bin the data
num_bins = 20
bin_labels = [i for i in range(num_bins)]
gene_df['bin'] = pd.cut(gene_df['mean'], bins=num_bins, labels=bin_labels)

# %%
gene_df['bin'].value_counts()
# Out:
# bin
# 0     11846
# 1       752
# 2       201
# 3       106
# 4        55
# 5        36
# 6        25
# 13       17
# 10       17
# 8        17
# 7        17
# 12       16
# 9        14
# 11       13
# 15       12
# 14       11
# 16        3
# 17        3
# 19        3
# 18        0
# Name: count, dtype: int64

# %%
sns.scatterplot(gene_df, x='mean', y='var', hue='bin', palette='flag')
plt.title('Log - Mean vs variance')
plt.xlabel('Log - Mean')
plt.ylabel('Log - Variance')
# Out:
# Text(0, 0.5, 'Log - Variance')

# %%
# Find variance to mean ratio
gene_df['dispersion'] = gene_df['var'] / gene_df['mean']

# %%
# Find mean and standard deviatiin
gene_df_grouped = gene_df.groupby('bin')['dispersion']
bin_means = gene_df_grouped.mean()
bin_stds = gene_df_grouped.std(ddof=1)
# Out:
# <ipython-input-36-562d03bee84d>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gene_df_grouped = gene_df.groupby('bin')['dispersion']

# %%
# Normalize dispersion inside each bin
gene_df['dispersions_norm'] = (
    gene_df['dispersion'].to_numpy() - bin_means[gene_df['bin'].to_numpy()].to_numpy()
) / bin_stds[gene_df['bin'].to_numpy()].to_numpy()

# %%
# Reset the index of the DataFrame to ensure unique labels
gene_df = gene_df.reset_index()

# Now try plotting again
sns.scatterplot(gene_df, x='mean', y='dispersions_norm')

plt.title('Log - Mean vs custom dispersion')
plt.xlabel('Log - Mean')
plt.ylabel('Log - Custom dispersion')
# Out:
# Text(0, 0.5, 'Log - Custom dispersion')

# %%
# Sort genes by coefficient of variation
gene_df = gene_df.sort_values('dispersions_norm', ascending=False)

# Keep 2000 genes with highest coefficient of variation
highly_variable_genes = gene_df['index'][:2000] # Use the 'index' column to get original gene names

# Subset the expression matrix to highly variable genes
expression_df = expression_df.loc[:, highly_variable_genes]

# %% [markdown]
# ## Dimensionality reduction

# %%
# Run PCA
pca = PCA()
pca_transformed_data = pca.fit_transform(expression_df.to_numpy())

# %%
# Perform knee detection
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)*100

kneedle = KneeLocator(
    range(len(cumulative_explained_variance)),
    cumulative_explained_variance,
    S=1.0,
    curve="concave",
    direction="increasing"
)
kneedle.plot_knee()

# %% [markdown]
# Number of principal components is choosen to be 50. This is frequent choice for this analysis type.

# %%
# Extract subset of principal components
elbow_point = kneedle.elbow
pca_transformed_data = pca_transformed_data[:, :50]

# %%
# Run umap
umap_obj = umap.UMAP()
embedding = umap_obj.fit_transform(pca_transformed_data)

# %% [markdown]
# #### Following peripheral blood mononuclear cells (PBMCs) are present in this dataset.
#
#
# - **B Cells**
#   - **What They Do**: Make "tags" (antibodies) that stick to germs and mark them for destruction.
#   - **Main Role**: Help the immune system recognize and remember germs.
#   - **Why Different**: Only cells that make antibodies to tag specific germs.
#
# <!-- Empty Line After Main Bullet -->
#
#
# - **Dendritic Cells (DCs)**
#   - **What They Do**: Capture germs and show pieces to other immune cells.
#   - **Main Role**: Alert the immune system about invaders.
#   - **Why Different**: Messengers between the first-line and specialized immune defenses.
#
# <!-- Empty Line After Main Bullet -->
#
#
# - **CD14+ Monocytes**
#   - **What They Do**: Suck up germs, break them apart, and can change into macrophages.
#   - **Main Role**: Clean up and later transform into tissue-specific cells for ongoing defense.
#   - **Why Different**: Versatile; can transform and become part of tissue defenses.
#
# <!-- Empty Line After Main Bullet -->
#
#
# - **Natural Killer (NK) cells**
#   - **What They Do**: Patrol and kill infected or cancerous cells without needing specific tags.
#   - **Main Role**: Quick response to a wide range of problems.
#   - **Why Different**: Can act without needing to recognize specific germs.
#
# <!-- Empty Line After Main Bullet -->
#
#
# - **CD8 T cells**
#   - **What They Do**: Directly kill infected or cancerous cells.
#   - **Main Role**: Eliminate specifically tagged cells.
#   - **Why Different**: The "assassins" that directly kill target cells.
#
# <!-- Empty Line After Main Bullet -->
#
#
# - **Naive CD4 T cells**
#   - **What They Do**: Wait to be activated to fight specific germs.
#   - **Main Role**: Ready to be trained for fighting specific invaders.
#   - **Why Different**: Untrained soldiers waiting for their first mission.
#
# <!-- Empty Line After Main Bullet -->
#
#
# - **Memory CD4 T cells**
#   - **What They Do**: Remember past germs and react faster next time.
#   - **Main Role**: Quick response to known threats.
#   - **Why Different**: The immune system's "record keepers."
#
# <!-- Empty Line After Main Bullet -->
#
# - **FCGR3A+ Monocytes**
#   - **What They Do**: Work with antibodies to make them more effective at tagging germs.
#   - **Main Role**: Boost the effectiveness of antibodies.
#   - **Why Different**: Have a special "hook" (FCGR3A) that enhances their cooperation with antibodies.
#
# <!-- Empty Line After Main Bullet -->
#
#
# - **Platelets**
#   - **What They Do**: Help blood to clot.
#   - **Main Role**: Stop bleeding.
#   - **Why Different**: Not directly involved in fighting germs but crucial for preventing blood loss.

# %%
# Plot umap embedding and display cell types
labels = [cell_type_dict[cell_id] if cell_id in cell_type_dict else 'none' for cell_id in expression_df.index ]
uplot.points(umap_obj, labels=np.array(labels))
# Out:
# <Axes: >

# %% [markdown]
# ## Attempt to cluster the data with K-means

# %%
inertia_list = []
silhouette_score_list = []

# List used to store clusterings
clustering_result_dict = {}

# List used to store k means objects
k_means_list = []

num_clusters = range(3,15)

for num_clust in num_clusters:

    # Perform clustering for current number of clusters
    kmeans = KMeans(n_clusters=num_clust, n_init='auto', random_state=42)
    kmeans.fit(pca_transformed_data)

    k_means_list.append(kmeans)

    # Calculate inertia
    inertia_list.append(kmeans.inertia_)

    # Add clustering result to list
    silhouette_scr = silhouette_score(pca_transformed_data, kmeans.labels_)
    silhouette_score_list.append(silhouette_scr)

    clustering_result_dict[num_clust] = np.array(kmeans.labels_)

# %%
# Siluethe plot
plt.plot(num_clusters, silhouette_score_list)
plt.title('Silhouette score')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score value')
# Out:
# Text(0, 0.5, 'Silhouette score value')

# %%
# Plot inertia plot and curve
kneedle = KneeLocator(
    num_clusters,
    inertia_list,
    S=2,
    curve="convex",
    direction="decreasing"
)
kneedle.plot_knee()

# %%
uplot.points(umap_obj, labels=np.array(labels))
# Out:
# <Axes: >

# %%
umap.plot.connectivity(umap_obj, show_points=True,labels=np.array(labels))
# Out:
# <Axes: >

# %%
umap.plot.diagnostic(umap_obj, diagnostic_type='pca')
# Out:
# <Axes: title={'center': 'Colored by RGB coords of PCA embedding'}>

# %%
num_clust_list = [3,4,5,6,7,8,9]

# Initialize the grid of plots
fig, axs = plt.subplots(
    len(num_clust_list), 3,
    figsize=(16, 30)
)

tab10 = list(matplotlib.colormaps['tab10'].colors)

# Loop to populate the grid with plots
for i in range(len(num_clust_list)):

    sns.scatterplot(
        x=embedding[:,0],
        y=embedding[:,1],
        hue=clustering_result_dict[num_clust_list[i]],
        ax=axs[i, 0],
        s=3, palette='tab10'
    )

    visualizer = SilhouetteVisualizer(
        k_means_list[i],
        is_fitted=True,
        colors=tab10,
        ax=axs[i, 1]
    )

    visualizer = visualizer.fit(pca_transformed_data)

    sns.scatterplot(
        x=embedding[:,0],
        y=embedding[:,1],
        hue=np.array(labels),
        ax=axs[i, 2],
        s=3, palette='tab10'
    )
    axs[i,0].set_title('K-means clusters, K={}'.format(num_clust_list[i]))
    axs[i,1].set_title('True cell types')

plt.show()

# %%
adj_rand_score_list = []
for clust_num in clustering_result_dict:

    adj_rand_score_list.append(adjusted_rand_score(clustering_result_dict[clust_num], labels))

plt.plot(clustering_result_dict.keys(), adj_rand_score_list)
plt.title('Adjusted rand score')
# Out:
# Text(0.5, 1.0, 'Adjusted rand score')

# %% [markdown]
# ### Describing the clusters - K=7

# %%
# Get cells bellonging to cluster 6
current_clust = clustering_result_dict[7]
current_clust

bcells_idx = np.where(current_clust==6)
other_clust_idx = np.where(current_clust!=6)

# %%
from scipy.stats import mannwhitneyu

result_df = pd.DataFrame(columns=['ratio', 'pvalue'])

# Iterate through genes
for gene in full_expression_df.columns:

    # Get expression values for current gene
    curr_gene_exp = full_expression_df[gene].to_numpy()

    # Extract values belinging to cluster 2
    bcells_exp = curr_gene_exp[bcells_idx]
    # Extract values belonging to other clusters
    other_exp = curr_gene_exp[other_clust_idx]

    # Find ration of mean values
    mean_bcells = np.mean(bcells_exp) + 0.0001
    mean_others = np.mean(other_exp) + 0.0001

    ratio = mean_bcells/mean_others

    # Perform statistical testing
    ranksum_res = mannwhitneyu(bcells_exp, other_exp, alternative='greater')

    if ranksum_res.pvalue is not None:
        result_df.loc[gene, 'ratio'] = ratio
        result_df.loc[gene, 'pvalue'] = ranksum_res.pvalue

# %%
result_df['pvalue'] = pd.to_numeric(result_df['pvalue'], errors='coerce')

# %%
result_df.sort_values(['pvalue', 'ratio'], ascending=True).head(10)
# Out:
#             ratio         pvalue
# LGALS2   7.627373  1.626416e-181
# CPVL    10.461572  1.635770e-143
# CST3      4.26412  3.135022e-127
# MS4A6A   6.865344  6.106592e-127
# CFP      5.798756  1.262193e-124
# FCN1     4.746956  1.502537e-120
# TYMP     4.041922  1.404070e-114
# GRN      5.075811  3.606101e-114
# CD14     6.938212  6.209682e-114
# ALDH2    7.951009  1.939969e-111

# %%
uplot.points(
    umap_obj,
    values=full_expression_df['MS4A1'].to_numpy(),
    width=600, height=600
)
plt.title('MS4A1 gene expression - B-cell marker')
# Out:
# Text(0.5, 1.0, 'MS4A1 gene expression - B-cell marker')

# %%
uplot.points(
    umap_obj,
    values=full_expression_df['CD79A'].to_numpy(),
    width=600, height=600
)
plt.title('CD79A gene expression - B-cell marker')
# Out:
# Text(0.5, 1.0, 'CD79A gene expression - B-cell marker')
